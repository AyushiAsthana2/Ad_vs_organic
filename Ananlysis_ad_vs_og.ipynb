# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Ayushi Asthana\\Desktop\\vidooly\\ad_vs_org\\final_combined_organic_duration.csv')
# Out:
# C:\Users\Ayushi Asthana\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (3,22,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#data['publishedAt'].dt.time
data['publishedAt'] = pd.to_datetime(data['publishedAt'])

# %%
data['publishedAt']=data['publishedAt'].dt.date

# %%
data['Channel Publish date'] = pd.to_datetime(data['Channel Publish date'])

# %%
data['Channel Publish date']=data['Channel Publish date'].dt.date

# %%
data.columns
# Out:
# Index(['vid', 'channelId', 'duration', 'licensedContent', 'definition',
#        'dislikeCount', 'commentCount', 'favoriteCount', 'viewCount',
#        'likeCount', 'relevantTopicIds', 'topicIds', 'topicCategories', 'title',
#        'description', 'tags', 'categoryId', 'channelTitle', 'publishedAt',
#        'Channel Title', 'Channel Description', 'Channel Publish date',
#        ' Channel hiddenSubscriberCount', 'Channel viewCount',
#        'Channel subscriberCount', 'Channel commentCount', 'Channel videoCount',
#        'Channel showRelatedChannels', 'Channel featuredChannelsUrls',
#        'Channel noOfFeaturedChannels', 'Channel country', 'Channel keywords',
#        'Channel topicIds', 'Channel topicCategories'],
#       dtype='object')

# %% [markdown]
# # Preprocessing data

# %%
df=data['Channel topicIds']

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
df2=pd.read_csv('C:\\Users\\Ayushi Asthana\\Desktop\\vidooly\\ad_vs_org\\resultstats.csv')

# %%
#A.merge(B, left_on='lkey', right_on='rkey', how='outer')
data1=data.merge(df2,left_on='vid',right_on='video_id',how='inner')

# %%
data1.head()
# Out:
#            vid                 channelId  duration licensedContent definition  \
# 0  mqZsF63zEN4  UC-4k5iBbLA1Q1qELNvjagCA    1375.0            True         hd
# 1  S9UM-hOBGiA  UC-4k5iBbLA1Q1qELNvjagCA     126.0            True         hd
# 2  omZDTXUNXUU  UC-4k5iBbLA1Q1qELNvjagCA    1354.0            True         hd
# 3  E2XB_V-6dwU  UC-4k5iBbLA1Q1qELNvjagCA    1482.0            True         hd
# 4  3lDqDhyKBwg  UC-4k5iBbLA1Q1qELNvjagCA     607.0            True         hd
#
#    dislikeCount  commentCount  favoriteCount  viewCount  likeCount  \
# 0           5.0          20.0            0.0   286118.0     1256.0
# 1           3.0           0.0            0.0   262925.0       10.0
# 2           7.0          21.0            0.0   301233.0       30.0
# 3           6.0          31.0            0.0   309189.0     1104.0
# 4          17.0          21.0            0.0    41380.0      130.0
#
#       ...                            Channel featuredChannelsUrls  \
# 0     ...       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 1     ...       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 2     ...       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 3     ...       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 4     ...       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
#
#   Channel noOfFeaturedChannels Channel country  \
# 0                          4.0              VN
# 1                          4.0              VN
# 2                          4.0              VN
# 3                          4.0              VN
# 4                          4.0              VN
#
#                                     Channel keywords  \
# 0  "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 1  "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 2  "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 3  "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 4  "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
#
#                                     Channel topicIds  \
# 0  ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 1  ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 2  ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 3  ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 4  ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
#
#                              Channel topicCategories  Unnamed: 0        ad%  \
# 0  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          65  28.055425
# 1  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          93  98.889202
# 2  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          97  98.789506
# 3  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          83  52.534355
# 4  ['https://en.wikipedia.org/wiki/Lifestyle_(soc
# 2            30.0    ...                  118.0                        True
# 3          1104.0    ...                  118.0                        True
# 4           130.0    ...                  118.0                        True
# 5           129.0    ...                  118.0                        True
# 6          1189.0    ...                  118.0                        True
# 7            12.0    ...                  118.0                        True
# 8          2666.0    ...                  118.0                        True
# 9          1468.0    ...                  118.0                        True
# 10          130.0    ...                  118.0                        True
# 11            4.0    ...                  118.0                        True
# 12            1.0    ...                  118.0                        True
# 13           53.0    ...                  118.0                        True
# 14          109.0    ...                  118.0                        True
# 15            3.0    ...                  118.0                        True
# 16          176.0    ...                  118.0                        True
# 17            7.0    ...                  118.0                        True
# 18          187.0    ...                  118.0                        True
# 19            4.0    ...                  118.0                        True
# 20          115.0    ...                  118.0                        True
# 21          176.0    ...                  118.0                        True
# 22            2.0    ...                  118.0                        True
# 23           34.0    ...                  118.0                        True
# 24           84.0    ...                  118.0                        True
# 25            7.0    ...                  118.0                        True
# 26            9.0    ...                  118.0                        True
# 27          100.0    ...                  118.0                        True
# 28          168.0    ...                  118.0                        True
# 29            3.0    ...                  118.0                        True
# ...           ...    ...                    ...                         ...
# 238155       23.0    ...                   98.0                        True
# 238156       17.0    ...                   98.0                        True
# 238157       51.0    ...                   98.0                        True
# 238158       17.0    ...                   98.0                        True
# 238159       10.0    ...                   98.0                        True
# 238160       56.0    ...                   98.0                        True
# 238161       41.0    ...                   98.0                        True
# 238162       20.0    ...                   98.0                        True
# 238163       17.0    ...                   98.0                        True
# 238164       20.0    ...                   98.0                        True
# 238165      157.0    ...                   98.0                        True
# 238166       26.0    ...                   98.0                        True
# 238167      159.0    ...                   98.0                        True
# 238168       49.0    ...                   98.0                        True
# 238169        7.0    ...                   98.0                        True
# 238170       42.0    ...                   98.0                        True
# 238171        3.0    ...                   98.0                        True
# 238172       20.0    ...                   98.0                        True
# 238173        9.0    ...                   98.0                        True
# 238174       28.0    ...                   98.0                        True
# 238175       80.0    ...                   98.0                        True
# 238176       13.0    ...                   98.0                        True
# 238177        8.0    ...                   98.0                        True
# 238178       35.0    ...                   98.0                        True
# 238179        8.0    ...                   98.0                        True
# 238180        3.0    ...                   98.0                        True
# 238181        6.0    ...                   98.0                        True
# 238182     2496.0    ...                   98.0                        True
# 238183       27.0    ...                   98.0                        True
# 238184      156.0    ...                   98.0                        True
#
#                              Channel featuredChannelsUrls  \
# 0       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 1       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 2       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 3       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 4       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 5       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 6       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 7       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 8       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 9       ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 10      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 11      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 12      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 13      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 14      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 15      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 16      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 17      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 18      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 19      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 20      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 21      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 22      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 23      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 24      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 25      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 26      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 27      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 28      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# 29      ['UCRNqZ5sx-i4DiIeIIJkj0zw', 'UCL54b9VGj73ux8w...
# ...                                                   ...
# 238155  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238156  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238157  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238158  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238159  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238160  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238161  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238162  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238163  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238164  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238165  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238166  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238167  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238168  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238169  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238170  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238171  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238172  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238173  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238174  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238175  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238176  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238177  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238178  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238179  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238180  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238181  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238182  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238183  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
# 238184  ['UCO1U9Jwy_mtXcsC4Z0NH3Bg', 'UCdwQOUt3ns-BSWl...
#
#        Channel noOfFeaturedChannels Channel country  \
# 0                               4.0              VN
# 1                               4.0              VN
# 2                               4.0              VN
# 3                               4.0              VN
# 4                               4.0              VN
# 5                               4.0              VN
# 6                               4.0              VN
# 7                               4.0              VN
# 8                               4.0              VN
# 9                               4.0              VN
# 10                              4.0              VN
# 11                              4.0              VN
# 12                              4.0              VN
# 13                              4.0              VN
# 14                              4.0              VN
# 15                              4.0              VN
# 16                              4.0              VN
# 17                              4.0              VN
# 18                              4.0              VN
# 19                              4.0              VN
# 20                              4.0              VN
# 21                              4.0              VN
# 22                              4.0              VN
# 23                              4.0              VN
# 24                              4.0              VN
# 25                              4.0              VN
# 26                              4.0              VN
# 27                              4.0              VN
# 28                              4.0              VN
# 29                              4.0              VN
# ...                             ...             ...
# 238155                          5.0             NaN
# 238156                          5.0             NaN
# 238157                          5.0             NaN
# 238158                          5.0             NaN
# 238159                          5.0             NaN
# 238160                          5.0             NaN
# 238161                          5.0             NaN
# 238162                          5.0             NaN
# 238163                          5.0             NaN
# 238164                          5.0             NaN
# 238165                          5.0             NaN
# 238166                          5.0             NaN
# 238167                          5.0             NaN
# 238168                          5.0             NaN
# 238169                          5.0             NaN
# 238170                          5.0             NaN
# 238171                          5.0             NaN
# 238172                          5.0             NaN
# 238173                          5.0             NaN
# 238174                          5.0             NaN
# 238175                          5.0             NaN
# 238176                          5.0             NaN
# 238177                          5.0             NaN
# 238178                          5.0             NaN
# 238179                          5.0             NaN
# 238180                          5.0             NaN
# 238181                          5.0             NaN
# 238182                          5.0             NaN
# 238183                          5.0             NaN
# 238184                          5.0             NaN
#
#                                          Channel keywords  \
# 0       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 1       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 2       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 3       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 4       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 5       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 6       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 7       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 8       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 9       "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 10      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 11      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 12      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 13      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 14      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 15      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 16      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 17      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 18      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 19      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 20      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 21      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 22      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 23      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 24      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 25      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 26      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 27      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 28      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# 29      "nhỏ to cùng mẹ" "nho to cung me" "moms in tow...
# ...                                                   ...
# 238155  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238156  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238157  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238158  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238159  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238160  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238161  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238162  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238163  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238164  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238165  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238166  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238167  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238168  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238169  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238170  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238171  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238172  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238173  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238174  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238175  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238176  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238177  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238178  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238179  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238180  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238181  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238182  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238183  "Comedy Videos" "Funniest Videos" "Why Indian ...
# 238184  "Comedy Videos" "Funniest Videos" "Why Indian ...
#
#                                          Channel topicIds  \
# 0       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 1       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 2       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 3       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 4       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 5       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 6       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 7       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 8       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 9       ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 10      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 11      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 12      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 13      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 14      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 15      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 16      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 17      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 18      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 19      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 20      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 21      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 22      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 23      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 24      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 25      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 26      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 27      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 28      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# 29      ['/m/019_rr', '/m/019_rr', '/m/02jjt', '/m/02v...
# ...                                                   ...
# 238155                           ['/m/02vxn', '/m/02jjt']
# 238156                           ['/m/02vxn', '/m/02jjt']
# 238157                           ['/m/02vxn', '/m/02jjt']
# 238158                           ['/m/02vxn', '/m/02jjt']
# 238159                           ['/m/02vxn', '/m/02jjt']
# 238160                           ['/m/02vxn', '/m/02jjt']
# 238161                           ['/m/02vxn', '/m/02jjt']
# 238162                           ['/m/02vxn', '/m/02jjt']
# 238163                           ['/m/02vxn', '/m/02jjt']
# 238164                           ['/m/02vxn', '/m/02jjt']
# 238165                           ['/m/02vxn', '/m/02jjt']
# 238166                           ['/m/02vxn', '/m/02jjt']
# 238167                           ['/m/02vxn', '/m/02jjt']
# 238168                           ['/m/02vxn', '/m/02jjt']
# 238169                           ['/m/02vxn', '/m/02jjt']
# 238170                           ['/m/02vxn', '/m/02jjt']
# 238171                           ['/m/02vxn', '/m/02jjt']
# 238172                           ['/m/02vxn', '/m/02jjt']
# 238173                           ['/m/02vxn', '/m/02jjt']
# 238174                           ['/m/02vxn', '/m/02jjt']
# 238175                           ['/m/02vxn', '/m/02jjt']
# 238176                           ['/m/02vxn', '/m/02jjt']
# 238177                           ['/m/02vxn', '/m/02jjt']
# 238178                           ['/m/02vxn', '/m/02jjt']
# 238179                           ['/m/02vxn', '/m/02jjt']
# 238180                           ['/m/02vxn', '/m/02jjt']
# 238181                           ['/m/02vxn', '/m/02jjt']
# 238182                           ['/m/02vxn', '/m/02jjt']
# 238183                           ['/m/02vxn', '/m/02jjt']
# 238184                           ['/m/02vxn', '/m/02jjt']
#
#                                   Channel topicCategories Unnamed: 0  \
# 0       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         65
# 1       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         93
# 2       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         97
# 3       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         83
# 4       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         43
# 5       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         52
# 6       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...        110
# 7       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         26
# 8       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         25
# 9       ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         55
# 10      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         61
# 11      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         80
# 12      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...        112
# 13      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         89
# 14      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         14
# 15      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         64
# 16      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         44
# 17      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...        114
# 18      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...        106
# 19      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         40
# 20      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         77
# 21      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         24
# 22      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          9
# 23      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         95
# 24      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         71
# 25      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          2
# 26      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         53
# 27      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         27
# 28      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...          1
# 29      ['https://en.wikipedia.org/wiki/Lifestyle_(soc...         66
# ...                                                   ...        ...
# 238155  ['https://en.wikipedia.org/wiki/Entertainment'...     245838
# 238156  ['https://en.wikipedia.org/wiki/Entertainment'...     245792
# 238157  ['https://en.wikipedia.org/wiki/Entertainment'...     245803
# 238158  ['https://en.wikipedia.org/wiki/Entertainment'...     245778
# 238159  ['https://en.wikipedia.org/wiki/Entertainment'...     245794
# 238160  ['https://en.wikipedia.org/wiki/Entertainment'...     245851
# 238161  ['https://en.wikipedia.org/wiki/Entertainment'...     245840
# 238162  ['https://en.wikipedia.org/wiki/Entertainment'...     245860
# 238163  ['https://en.wikipedia.org/wiki/Entertainment'...     245858
# 238164  ['https://en.wikipedia.org/wiki/Entertainment'...     245854
# 238165  ['https://en.wikipedia.org/wiki/Entertainment'...     245797
# 238166  ['https://en.wikipedia.org/wiki/Entertainment'...     245812
# 238167  ['https://en.wikipedia.org/wiki/Entertainment'...     245790
# 238168  ['https://en.wikipedia.org/wiki/Entertainment'...     245869
# 238169  ['https://en.wikipedia.org/wiki/Entertainment'...     245856
# 238170  ['https://en.wikipedia.org/wiki/Entertainment'...     245867
# 238171  ['https://en.wikipedia.org/wiki/Entertainment'...     245814
# 238172  ['https://en.wikipedia.org/wiki/Entertainment'...     245853
# 238173  ['https://en.wikipedia.org/wiki/Entertainment'...     245855
# 238174  ['https://en.wikipedia.org/wiki/Entertainment'...     245793
# 238175  ['https://en.wikipedia.org/wiki/Entertainment'...     245861
# 238176  ['https://en.wikipedia.org/wiki/Entertainment'...     245823
# 238177  ['https://en.wikipedia.org/wiki/Entertainment'...     245832
# 238178  ['https://en.wikipedia.org/wiki/Entertainment'...     245836
# 238179  ['https://en.wikipedia.org/wiki/Entertainment'...     245849
# 238180  ['https://en.wikipedia.org/wiki/Entertainment'...     245776
# 238181  ['https://en.wikipedia.org/wiki/Entertainment'...     245844
# 238182  ['https://en.wikipedia.org/wiki/Entertainment'...     245846
# 238183  ['https://en.wikipedia.org/wiki/Entertainment'...     245775
# 238184  ['https://en.wikipedia.org/wiki/Entertainment'...     245801
#
#               ad%
# 0       28.055425
# 1       98.889202
# 2       98.789506
# 3       52.534355
# 4        0.000000
# 5        0.000000
# 6       94.622702
# 7        0.000000
# 8        0.014844
# 9       30.686881
# 10      84.797145
# 11       0.000000
# 12       0.000000
# 13      11.032409
# 14       0.000000
# 15       0.000000
# 16       0.000000
# 17       0.000000
# 18       0.000000
# 19       0.000000
# 20       0.000000
# 21       0.000000
# 22       4.535637
# 23       0.039888
# 24       0.000000
# 25       0.000000
# 26      91.803393
# 27       0.000000
# 28       0.000000
# 29       0.787402
# ...           ...
# 238155   0.000000
# 238156   0.000000
# 238157   0.000000
# 238158   0.000000
# 238159   0.000000
# 238160   0.000000
# 238161   0.000000
# 238162   0.059880
# 238163   0.000000
# 238164   0.000000
# 238165   0.000000
# 238166   0.000000
# 238167   0.000000
# 238168   0.000000
# 238169   0.000000
# 238170   0.000000
# 238171   0.000000
# 238172   0.000000
# 238173   0.000000
# 238174   0.000000
# 238175   0.000000
# 238176   0.000000
# 238177   0.000000
# 238178   0.000000
# 238179   0.000000
# 238180   0.000000
# 238181   0.000000
# 238182   0.000000
# 238183   0.000000
# 238184   0.003529
#
# [238185 rows x 36 columns]

# %% [markdown]
# # Encoding data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb_make = LabelEncoder()
data1['vid'] = lb_make.fit_transform(data1['vid'])

data1.head() #Results in appending a new column to df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4963aa2a4c55> in <module>()
#       1 lb_make = LabelEncoder()
# ----> 2 data1['vid'] = lb_make.fit_transform(data1['vid'])
#       3
#       4 data1.head() #Results in appending a new column to df
#
# NameError: name 'data1' is not defined

# %%
lb_make = LabelEncoder()
data1['channelId'] = lb_make.fit_transform(data1['channelId'])

data1.head()

# %% [markdown]
# for k in data1['licensedContent']:
#     if k==True:
#         k=0
#     else:
#         k=1

# %%
data1.drop("Channel topicCategories",axis=1,inplace=True)
data1.drop("Channel featuredChannelsUrls",axis=1,inplace=True)
data1.drop("Channel topicIds",axis=1,inplace=True)
data1.drop("Channel keywords",axis=1,inplace=True)

# %%
lb_make = LabelEncoder()
data1['Channel Publish date'] = lb_make.fit_transform(data1['Channel Publish date'])
data1.head()
# Out:
#       vid  channelId  duration licensedContent definition  dislikeCount  \
# 0  189318          0    1375.0            True         hd           5.0
# 1  108600          0     126.0            True         hd           3.0
# 2  196537          0    1354.0            True         hd           7.0
# 3   56198          0    1482.0            True         hd           6.0
# 4   17763          0     607.0            True         hd          17.0
#
#    commentCount  favoriteCount  viewCount  likeCount    ...      \
# 0          20.0            0.0   286118.0     1256.0    ...
# 1           0.0            0.0   262925.0       10.0    ...
# 2          21.0            0.0   301233.0       30.0    ...
# 3          31.0            0.0   309189.0     1104.0    ...
# 4          21.0            0.0    41380.0      130.0    ...
#
#    Channel hiddenSubscriberCount Channel viewCount Channel subscriberCount  \
# 0                          False         8740487.0                 16085.0
# 1                          False         8740487.0                 16085.0
# 2                          False         8740487.0                 16085.0
# 3                          False         8740487.0                 16085.0
# 4                          False         8740487.0                 16085.0
#
#   Channel commentCount Channel videoCount Channel showRelatedChannels  \
# 0                  0.0              118.0                        True
# 1                  0.0              118.0                        True
# 2                  0.0              118.0                        True
# 3                  0.0              118.0                        True
# 4                  0.0              118.0                        True
#
#    Channel noOfFeaturedChannels Channel country Unnamed: 0        ad%
# 0                           4.0              VN         65  28.055425
# 1                           4.0              VN         93  98.889202
# 2                           4.0              VN         97  98.789506
# 3                           4.0              VN         83  52.534355
# 4                           4.0              VN         43   0.000000
#
# [5 rows x 32 columns]

# %% [markdown]
# lb_make = LabelEncoder()
# data1['Channel country'] = lb_make.fit_transform(data1['Channel country'])
# data1.head()

# %%
data1.head()
# Out:
#       vid  channelId  duration licensedContent definition  dislikeCount  \
# 0  189318          0    1375.0            True         hd           5.0
# 1  108600          0     126.0            True         hd           3.0
# 2  196537          0    1354.0            True         hd           7.0
# 3   56198          0    1482.0            True         hd           6.0
# 4   17763          0     607.0            True         hd          17.0
#
#    commentCount  favoriteCount  viewCount  likeCount    ...      \
# 0          20.0            0.0   286118.0     1256.0    ...
# 1           0.0            0.0   262925.0       10.0    ...
# 2          21.0            0.0   301233.0       30.0    ...
# 3          31.0            0.0   309189.0     1104.0    ...
# 4          21.0            0.0    41380.0      130.0    ...
#
#    Channel hiddenSubscriberCount Channel viewCount Channel subscriberCount  \
# 0                          False         8740487.0                 16085.0
# 1                          False         8740487.0                 16085.0
# 2                          False         8740487.0                 16085.0
# 3                          False         8740487.0                 16085.0
# 4                          False         8740487.0                 16085.0
#
#   Channel commentCount Channel videoCount Channel showRelatedChannels  \
# 0                  0.0              118.0                        True
# 1                  0.0              118.0                        True
# 2                  0.0              118.0                        True
# 3                  0.0              118.0                        True
# 4                  0.0              118.0                        True
#
#    Channel noOfFeaturedChannels Channel country Unnamed: 0        ad%
# 0                           4.0              VN         65  28.055425
# 1                           4.0              VN         93  98.889202
# 2                           4.0              VN         97  98.789506
# 3                           4.0              VN         83  52.534355
# 4                           4.0              VN         43   0.000000
#
# [5 rows x 32 columns]

# %% [markdown]
# Y=data1["ad%"]
# data2=data1.iloc[:,:-1]
# model = ExtraTreesClassifier()
# model.fit(data2, Y)
# print(model.feature_importances_)

# %%
#data1.drop("Channel country",axis=1,inplace=True)
data1.drop("definition",axis=1,inplace=True)

# %%
data1.head()
# Out:
#       vid  channelId  duration licensedContent  dislikeCount  commentCount  \
# 0  189318          0    1375.0            True           5.0          20.0
# 1  108600          0     126.0            True           3.0           0.0
# 2  196537          0    1354.0            True           7.0          21.0
# 3   56198          0    1482.0            True           6.0          31.0
# 4   17763          0     607.0            True          17.0          21.0
#
#    favoriteCount  viewCount  likeCount           relevantTopicIds    ...      \
# 0            0.0   286118.0     1256.0               ['/m/02jjt']    ...
# 1            0.0   262925.0       10.0               ['/m/02jjt']    ...
# 2            0.0   301233.0       30.0                        NaN    ...
# 3            0.0   309189.0     1104.0               ['/m/02jjt']    ...
# 4            0.0    41380.0      130.0  ['/m/019_rr', '/m/0kt51']    ...
#
#    Channel hiddenSubscriberCount Channel viewCount Channel subscriberCount  \
# 0                          False         8740487.0                 16085.0
# 1                          False         8740487.0                 16085.0
# 2                          False         8740487.0                 16085.0
# 3                          False         8740487.0                 16085.0
# 4                          False         8740487.0                 16085.0
#
#   Channel commentCount Channel videoCount  Channel showRelatedChannels  \
# 0                  0.0              118.0                         True
# 1                  0.0              118.0                         True
# 2                  0.0              118.0                         True
# 3                  0.0              118.0                         True
# 4                  0.0              118.0                         True
#
#   Channel noOfFeaturedChannels Channel country Unnamed: 0        ad%
# 0                          4.0              VN         65  28.055425
# 1                          4.0              VN         93  98.889202
# 2                          4.0              VN         97  98.789506
# 3                          4.0              VN         83  52.534355
# 4                          4.0              VN         43   0.000000
#
# [5 rows x 31 columns]

# %%
data1.drop("relevantTopicIds",axis=1,inplace=True)

# %%
data1.drop("topicIds",axis=1,inplace=True)

# %%
data1.head()
# Out:
#       vid  channelId  duration licensedContent  dislikeCount  commentCount  \
# 0  189318          0    1375.0            True           5.0          20.0
# 1  108600          0     126.0            True           3.0           0.0
# 2  196537          0    1354.0            True           7.0          21.0
# 3   56198          0    1482.0            True           6.0          31.0
# 4   17763          0     607.0            True          17.0          21.0
#
#    favoriteCount  viewCount  likeCount  \
# 0            0.0   286118.0     1256.0
# 1            0.0   262925.0       10.0
# 2            0.0   301233.0       30.0
# 3            0.0   309189.0     1104.0
# 4            0.0    41380.0      130.0
#
#                                      topicCategories    ...      \
# 0    ['https://en.wikipedia.org/wiki/Entertainment']    ...
# 1    ['https://en.wikipedia.org/wiki/Entertainment']    ...
# 2                                                NaN    ...
# 3    ['https://en.wikipedia.org/wiki/Entertainment']    ...
# 4  ['https://en.wikipedia.org/wiki/Lifestyle_(soc...    ...
#
#    Channel hiddenSubscriberCount Channel viewCount Channel subscriberCount  \
# 0                          False         8740487.0                 16085.0
# 1                          False         8740487.0                 16085.0
# 2                          False         8740487.0                 16085.0
# 3                          False         8740487.0                 16085.0
# 4                          False         8740487.0                 16085.0
#
#    Channel commentCount Channel videoCount Channel showRelatedChannels  \
# 0                   0.0              118.0                        True
# 1                   0.0              118.0                        True
# 2                   0.0              118.0                        True
# 3                   0.0              118.0                        True
# 4                   0.0              118.0                        True
#
#   Channel noOfFeaturedChannels Channel country  Unnamed: 0        ad%
# 0                          4.0              VN          65  28.055425
# 1                          4.0              VN          93  98.889202
# 2                          4.0              VN          97  98.789506
# 3                          4.0              VN          83  52.534355
# 4                          4.0              VN          43   0.000000
#
# [5 rows x 29 columns]

# %%
data1['licensedContent'] = data1['licensedContent'].astype(int)

# %%
data1.drop("topicCategories",axis=1,inplace=True)
data1.drop("title",axis=1,inplace=True)

# %%
data1[' Channel hiddenSubscriberCount'] = data1[' Channel hiddenSubscriberCount'].astype(int)

# %%
data1.drop("topicIds",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f5508b3dc84c> in <module>()
# ----> 1 data1.drop("topicIds",axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['topicIds'] not contained in axis

# %%
data1.head()
# Out:
#       vid  channelId  duration  licensedContent  dislikeCount  commentCount  \
# 0  189318          0    1375.0                1           5.0          20.0
# 1  108600          0     126.0                1           3.0           0.0
# 2  196537          0    1354.0                1           7.0          21.0
# 3   56198          0    1482.0                1           6.0          31.0
# 4   17763          0     607.0                1          17.0          21.0
#
#    favoriteCount  viewCount  likeCount  \
# 0            0.0   286118.0     1256.0
# 1            0.0   262925.0       10.0
# 2            0.0   301233.0       30.0
# 3            0.0   309189.0     1104.0
# 4            0.0    41380.0      130.0
#
#                                          description    ...      \
# 0  Nhỏ To Cùng Mẹ | Phụ Nữ Xăm Mình Là Thần Thái ...    ...
# 1  Mỗi đêm, "Biệt đội cánh cụt" BINO siêu đáng yê...    ...
# 2  Nhỏ To Cùng Mẹ | Kim Nhã Đi Phẫu Thuật Thẩm Mỹ...    ...
# 3  Nhỏ To Cùng Mẹ | Trang Hạ & Phương Trinh nói "...    ...
# 4  Nhỏ To Cùng Mẹ | Nhật Ký Bí Bầu | Tuần 21 - Bù...    ...
#
#    Channel hiddenSubscriberCount  Channel viewCount Channel subscriberCount  \
# 0                          False          8740487.0                 16085.0
# 1                          False          8740487.0                 16085.0
# 2                          False          8740487.0                 16085.0
# 3                          False          8740487.0                 16085.0
# 4                          False          8740487.0                 16085.0
#
#   Channel commentCount Channel videoCount Channel showRelatedChannels  \
# 0                  0.0              118.0                        True
# 1                  0.0              118.0                        True
# 2                  0.0              118.0                        True
# 3                  0.0              118.0                        True
# 4                  0.0              118.0                        True
#
#    Channel noOfFeaturedChannels Channel country  Unnamed: 0        ad%
# 0                           4.0              VN          65  28.055425
# 1                           4.0              VN          93  98.889202
# 2                           4.0              VN          97  98.789506
# 3                           4.0              VN          83  52.534355
# 4                           4.0              VN          43   0.000000
#
# [5 rows x 27 columns]

# %%
#data1.drop("title",axis=1,inplace=True)
data1.drop("description",axis=1,inplace=True)

# %%
#data1.drop("title",axis=1,inplace=True)
data1.drop("tags",axis=1,inplace=True)

# %%
df1=data1['Channel showRelatedChannels']

# %%
df1.isnull().sum()
# Out:
# 38234

# %%
try:
    data1['Channel showRelatedChannels'] = data1['Channel showRelatedChannels'].astype(int)
except:
    data1['Channel showRelatedChannels']=False
    data1['Channel showRelatedChannels'] = data1['Channel showRelatedChannels'].astype(int)

# %% [markdown]
# df2=data1['Channel hiddenSubscriberCount']
#
# df2.isnull().sum()

# %%
data1['Channel showRelatedChannels'] = data1['Channel showRelatedChannels'].astype(int)

# %%
data1['Channel subscriberCount'].isnull().sum()
# Out:
# 0

# %%
data1.drop("channelTitle",axis=1,inplace=True)

# %%
data1.drop("Channel Title",axis=1,inplace=True)

# %%
data1.drop("Channel Description",axis=1,inplace=True)

# %%
data1.drop("Channel country",axis=1,inplace=True)

# %%
data1.columns
# Out:
# Index(['vid', 'channelId', 'duration', 'licensedContent', 'dislikeCount',
#        'commentCount', 'favoriteCount', 'viewCount', 'likeCount', 'categoryId',
#        'publishedAt', 'Channel Publish date', ' Channel hiddenSubscriberCount',
#        'Channel viewCount', 'Channel subscriberCount', 'Channel commentCount',
#        'Channel videoCount', 'Channel showRelatedChannels',
#        'Channel noOfFeaturedChannels', 'Unnamed: 0', 'ad%'],
#       dtype='object')

# %%
lb_make = LabelEncoder()
data1['publishedAt'] = lb_make.fit_transform(data1['publishedAt'])
data1.head()
# Out:
#       vid  channelId  duration  licensedContent  dislikeCount  commentCount  \
# 0  189318          0    1375.0                1           5.0          20.0
# 1  108600          0     126.0                1           3.0           0.0
# 2  196537          0    1354.0                1           7.0          21.0
# 3   56198          0    1482.0                1           6.0          31.0
# 4   17763          0     607.0                1          17.0          21.0
#
#    favoriteCount  viewCount  likeCount  categoryId    ...      \
# 0            0.0   286118.0     1256.0        24.0    ...
# 1            0.0   262925.0       10.0        24.0    ...
# 2            0.0   301233.0       30.0        24.0    ...
# 3            0.0   309189.0     1104.0        24.0    ...
# 4            0.0    41380.0      130.0        22.0    ...
#
#    Channel Publish date   Channel hiddenSubscriberCount  Channel viewCount  \
# 0                    89                               0          8740487.0
# 1                    89                               0          8740487.0
# 2                    89                               0          8740487.0
# 3                    89                               0          8740487.0
# 4                    89                               0          8740487.0
#
#    Channel subscriberCount  Channel commentCount  Channel videoCount  \
# 0                  16085.0                   0.0               118.0
# 1                  16085.0                   0.0               118.0
# 2                  16085.0                   0.0               118.0
# 3                  16085.0                   0.0               118.0
# 4                  16085.0                   0.0               118.0
#
#    Channel showRelatedChannels  Channel noOfFeaturedChannels  Unnamed: 0  \
# 0                            0                           4.0          65
# 1                            0                           4.0          93
# 2                            0                           4.0          97
# 3                            0                           4.0          83
# 4                            0                           4.0          43
#
#          ad%
# 0  28.055425
# 1  98.889202
# 2  98.789506
# 3  52.534355
# 4   0.000000
#
# [5 rows x 21 columns]

# %%
lb_make = LabelEncoder()
data1['Channel Publish date '] = lb_make.fit_transform(data1['Channel Publish date'])
data1.head()
# Out:
#       vid  channelId  duration  licensedContent  dislikeCount  commentCount  \
# 0  189318          0    1375.0                1           5.0          20.0
# 1  108600          0     126.0                1           3.0           0.0
# 2  196537          0    1354.0                1           7.0          21.0
# 3   56198          0    1482.0                1           6.0          31.0
# 4   17763          0     607.0                1          17.0          21.0
#
#    favoriteCount  viewCount  likeCount  categoryId          ...            \
# 0            0.0   286118.0     1256.0        24.0          ...
# 1            0.0   262925.0       10.0        24.0          ...
# 2            0.0   301233.0       30.0        24.0          ...
# 3            0.0   309189.0     1104.0        24.0          ...
# 4            0.0    41380.0      130.0        22.0          ...
#
#     Channel hiddenSubscriberCount  Channel viewCount  Channel subscriberCount  \
# 0                               0          8740487.0                  16085.0
# 1                               0          8740487.0                  16085.0
# 2                               0          8740487.0                  16085.0
# 3                               0          8740487.0                  16085.0
# 4                               0          8740487.0                  16085.0
#
#    Channel commentCount  Channel videoCount  Channel showRelatedChannels  \
# 0                   0.0               118.0                            0
# 1                   0.0               118.0                            0
# 2                   0.0               118.0                            0
# 3                   0.0               118.0                            0
# 4                   0.0               118.0                            0
#
#    Channel noOfFeaturedChannels  Unnamed: 0        ad%  Channel Publish date
# 0                           4.0          65  28.055425                     89
# 1                           4.0          93  98.889202                     89
# 2                           4.0          97  98.789506                     89
# 3                           4.0          83  52.534355                     89
# 4                           4.0          43   0.000000                     89
#
# [5 rows x 22 columns]

# %%
data1['Channel Publish date']
# Out:
# 0         89
# 1         89
# 2         89
# 3         89
# 4         89
# 5         89
# 6         89
# 7         89
# 8         89
# 9         89
# 10        89
# 11        89
# 12        89
# 13        89
# 14        89
# 15        89
# 16        89
# 17        89
# 18        89
# 19        89
# 20        89
# 21        89
# 22        89
# 23        89
# 24        89
# 25        89
# 26        89
# 27        89
# 28        89
# 29        89
#           ..
# 238155    47
# 238156    47
# 238157    47
# 238158    47
# 238159    47
# 238160    47
# 238161    47
# 238162    47
# 238163    47
# 238164    47
# 238165    47
# 238166    47
# 238167    47
# 238168    47
# 238169    47
# 238170    47
# 238171    47
# 238172    47
# 238173    47
# 238174    47
# 238175    47
# 238176    47
# 238177    47
# 238178    47
# 238179    47
# 238180    47
# 238181    47
# 238182    47
# 238183    47
# 238184    47
# Name: Channel Publish date, Length: 238185, dtype: int64

# %%
data1[' Channel hiddenSubscriberCount'] = data1[' Channel hiddenSubscriberCount'].astype(int)

# %%
Y=data1["ad%"]
data2=data1.iloc[:,:-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data2, Y, test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
data1.columns
# Out:
# Index(['vid', 'channelId', 'duration', 'licensedContent', 'dislikeCount',
#        'commentCount', 'favoriteCount', 'viewCount', 'likeCount', 'categoryId',
#        'publishedAt', 'Channel Publish date', ' Channel hiddenSubscriberCount',
#        'Channel viewCount', 'Channel subscriberCount', 'Channel commentCount',
#        'Channel videoCount', 'Channel showRelatedChannels',
#        'Channel noOfFeaturedChannels', 'Unnamed: 0', 'ad%',
#        'Channel Publish date '],
#       dtype='object')

# %%
data1.isnull().sum()
# Out:
# vid                                   0
# channelId                             0
# duration                              0
# licensedContent                       0
# dislikeCount                      46557
# commentCount                       7335
# favoriteCount                         0
# viewCount                            18
# likeCount                         46557
# categoryId                            0
# publishedAt                           0
# Channel Publish date                  0
#  Channel hiddenSubscriberCount        0
# Channel viewCount                     0
# Channel subscriberCount               0
# Channel commentCount                  0
# Channel videoCount                    0
# Channel showRelatedChannels           0
# Channel noOfFeaturedChannels      14230
# Unnamed: 0                            0
# ad%                                   0
# Channel Publish date                  0
# dtype: int64

# %%
data1.fillna(0, inplace=True)

# %%
data1.isnull().sum()
# Out:
# vid                               0
# channelId                         0
# duration                          0
# licensedContent                   0
# dislikeCount                      0
# commentCount                      0
# favoriteCount                     0
# viewCount                         0
# likeCount                         0
# categoryId                        0
# publishedAt                       0
# Channel Publish date              0
#  Channel hiddenSubscriberCount    0
# Channel viewCount                 0
# Channel subscriberCount           0
# Channel commentCount              0
# Channel videoCount                0
# Channel showRelatedChannels       0
# Channel noOfFeaturedChannels      0
# Unnamed: 0                        0
# ad%                               0
# Channel Publish date              0
# dtype: int64

# %%
data1.iloc[1]
# Out:
# vid                               1.086000e+05
# channelId                         0.000000e+00
# duration                          1.260000e+02
# licensedContent                   1.000000e+00
# dislikeCount                      3.000000e+00
# commentCount                      0.000000e+00
# favoriteCount                     0.000000e+00
# viewCount                         2.629250e+05
# likeCount                         1.000000e+01
# categoryId                        2.400000e+01
# publishedAt                       3.036000e+03
# Channel Publish date              8.900000e+01
#  Channel hiddenSubscriberCount    0.000000e+00
# Channel viewCount                 8.740487e+06
# Channel subscriberCount           1.608500e+04
# Channel commentCount              0.000000e+00
# Channel videoCount                1.180000e+02
# Channel showRelatedChannels       0.000000e+00
# Channel noOfFeaturedChannels      4.000000e+00
# Unnamed: 0                        9.300000e+01
# ad%                               9.888920e+01
# Channel Publish date              8.900000e+01
# Name: 1, dtype: float64

# %%
#data1.drop(' Channel hiddenSubscriberCount',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-47db0079c81e> in <module>()
# ----> 1 data1.drop(' Channel hiddenSubscriberCount',inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels [' Channel hiddenSubscriberCount'] not contained in axis

# %%
data1.columns
# Out:
# Index(['vid', 'channelId', 'duration', 'licensedContent', 'dislikeCount',
#        'commentCount', 'favoriteCount', 'viewCount', 'likeCount', 'categoryId',
#        'publishedAt', 'Channel Publish date', ' Channel hiddenSubscriberCount',
#        'Channel viewCount', 'Channel subscriberCount', 'Channel commentCount',
#        'Channel videoCount', 'Channel showRelatedChannels',
#        'Channel noOfFeaturedChannels', 'Unnamed: 0', 'ad%',
#        'Channel Publish date '],
#       dtype='object')

# %%
Y=y_train
X=X_train
model=ExtraTreesRegressor()
model.fit(X,Y)
print(model.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbd0e53b2fdd> in <module>()
# ----> 1 Y=y_train
#       2 X=X_train
#       3 model=ExtraTreesRegressor()
#       4 model.fit(X,Y)
#       5 print(model.feature_importances_)
#
# NameError: name 'y_train' is not defined

# %%
y=model.predict(X_test)

# %%
#from sklearn import metrics
model.score(y_test, y)

# %%
print(y)

# %%
data1.columns

# %%
data1.isnull().sum()

# %%
data1.fillna(0, inplace=True)

# %%
data1.head()

# %%
import matplotlib.pyplot as plt

# %%
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data1.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data1.columns)
ax.set_yticklabels(data1.columns)
plt.show()

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(18, 16))
corr = data1.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax,annot=True)
plt.show()

# %% [markdown]
# ## Chi-square test of independence

# %%
#print(y_tes
for k in y_test:
    if k>80:
        print(k)

# %%
k=data['publishedAt']

# %%
print(k)

# %%
k=pd.DataFrame(columns=k)

# %%
print(k.min(axis=1))

# %%
data1['Channel Publish date']

# %% [markdown]
# # Classification

# %%
data1.columns
# Out:
# Index(['vid', 'channelId', 'duration', 'licensedContent', 'dislikeCount',
#        'commentCount', 'favoriteCount', 'viewCount', 'likeCount', 'categoryId',
#        'publishedAt', 'Channel Publish date', ' Channel hiddenSubscriberCount',
#        'Channel viewCount', 'Channel subscriberCount', 'Channel commentCount',
#        'Channel videoCount', 'Channel showRelatedChannels',
#        'Channel noOfFeaturedChannels', 'Unnamed: 0', 'ad%'],
#       dtype='object')

# %%
label=[]

# %%
if data1['ad%']>0:
    label.append(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-22c97b29e08b> in <module>()
# ----> 1 if data1['ad%']>0:
#       2     label.append(1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
